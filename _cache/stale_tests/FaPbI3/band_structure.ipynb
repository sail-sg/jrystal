# %%
import numpy as np
import matplotlib.pyplot as plt

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
# jr_eigen = np.load("HHHHHPbCIIINN_band_structure.npy")*27.2114
jr_eigen = np.load("/home/aiops/litb/projects/jrystal/CC_band_structure.npy")*27.2114
jr_eigen.shape
# Out:
# (64, 14)

# %%
plt.figure(figsize=(4, 4))
# jr_eigen = jr_eigen.reshape(8, 8, -1)
# jr_eigen = np.reshape(jr_eigen, order="F", shape=(64, -1))
# 
# fermi = 0
fermi_idx = 4
fermi = np.max(jr_eigen[:, fermi_idx-1])


plt.plot(jr_eigen[:, :fermi_idx]-fermi, color="red")
plt.plot(jr_eigen[:, fermi_idx:]-fermi, color="blue")


# plt.ylim(-10, 10)
# plt.ylim(-5, 5)
plt.ylim(-50, 50)
# plt.ylim(-15, -5)
# plt.ylim(-90, -80)
# plt.ylim(-4, 4)
plt.show()
