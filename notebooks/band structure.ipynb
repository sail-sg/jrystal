# %% [markdown]
# # Band structure optimization

# %% [markdown]
# ### import the package

# %%
import jrystal

# %% [markdown]
# ### Load the configuration. You may want to modify yourself.

# %%
config = jrystal.config.get_config()
config.grid_sizes = 24
config.epoch = 2000
config.band_structure_epoch = config.epoch

# %% [markdown]
# ### Perform the band structure calculation.

# %%
eigenvalues = jrystal.band_structure.train(config)
# Out:
# INFO:absl:===> Starting total energy minimization...
# INFO:absl:===> Creating density module...
# INFO:absl: 1728 G points selected.
# INFO:absl: The size of G grid: (24, 24, 24)
# INFO:absl: The size of K points: (1,)
# INFO:absl: Estimated maximum of cutoff energy: 147.299 Ha
# Total energy: -55.848: 100%|██████████| 2000/2000 [00:13<00:00, 146.97it/s]
# INFO:absl: Converged: True.
# INFO:absl: Total epochs run: 2000.
# INFO:absl: Training Time: 13.630s.
# INFO:absl: Energy:
# INFO:absl: - Ground State: -55.84805020870047
# INFO:absl: - Kinetic: 43.91513766908412
# INFO:absl: - External: -79.56349166536062
# INFO:absl: - Exchange-Correlation: -2.645314993396198
# INFO:absl: - Hartree: 11.217468085900485
# INFO:absl: - Nucleus Repulsion: -28.771849304928253
# INFO:absl: Done total energy minimization.
# INFO:absl:===> Optimize the sum of band energies...
# INFO:absl:1 k points sampled.
# INFO:absl:10 bands will be computed.
# INFO:absl:===> Optimizing the first k point...
# ...

# %% [markdown]
# ### Visualization.

# %%
jrystal.visualization.plot_band_structure(eigenvalues, num_electrons = 12, ylim=(-20, 20))
